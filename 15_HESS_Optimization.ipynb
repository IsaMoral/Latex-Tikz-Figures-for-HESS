# %%
# prompt: Plotear idea de optimizacion en pdf

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Parámetros del modelo
I_RMS1 = 30 / np.log(2)  # Factor de corriente SC1
I_RMS2 = 30 / np.log(2)  # Factor de corriente SC2
I_total = 200  # Corriente total a distribuir (A)
num_points = 1000  # Resolución de la búsqueda

# Función de degradación total
def degradation(I1):
    return np.exp(I1 / I_RMS1) + np.exp((I_total - I1) / I_RMS2)

# Generar valores de I1
I1_values = np.linspace(0, I_total, num_points)
D_total = np.array([degradation(I1) for I1 in I1_values])

# Encontrar el mínimo
D_min = np.min(D_total)
idx = np.argmin(D_total)
I1_opt = I1_values[idx]

# Configuración del gráfico
plt.figure(figsize=(10, 6))  # Ajusta el tamaño de la figura
plt.plot(I1_values, D_total, 'b-', linewidth=1.5)
plt.scatter(I1_opt, D_min, s=100, c='r', marker='o')  # Usa 'o' como marcador de círculo

plt.xlabel('Corriente asignada al Supercapacitor 1, $I_1$ (A)', fontsize=12)
plt.ylabel('Degradación total, $D_{total}$', fontsize=12)
plt.title('Optimización de Distribución de Corriente', fontsize=14)
plt.grid(True)
plt.legend(['Degradación Total', 'Punto Óptimo'], loc='upper left', fontsize=10) # Ajusta la ubicación y tamaño de la leyenda

plt.show()

# %%
# prompt: exporta la imagen anterior en svg

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_svg import FigureCanvasSVG


# Parámetros del modelo
I_RMS1 = 30 / np.log(2)  # Factor de corriente SC1
I_RMS2 = 30 / np.log(2)  # Factor de corriente SC2
I_total = 200  # Corriente total a distribuir (A)
num_points = 1000  # Resolución de la búsqueda

# Función de degradación total
def degradation(I1):
    return np.exp(I1 / I_RMS1) + np.exp((I_total - I1) / I_RMS2)

# Generar valores de I1
I1_values = np.linspace(0, I_total, num_points)
D_total = np.array([degradation(I1) for I1 in I1_values])

# Encontrar el mínimo
D_min = np.min(D_total)
idx = np.argmin(D_total)
I1_opt = I1_values[idx]

# Configuración del gráfico
fig = plt.figure(figsize=(10, 6))  # Ajusta el tamaño de la figura
plt.plot(I1_values, D_total, 'b-', linewidth=1.5)
plt.scatter(I1_opt, D_min, s=100, c='r', marker='o')  # Usa 'o' como marcador de círculo

plt.xlabel('Corriente asignada al Supercapacitor 1, $I_1$ (A)', fontsize=12)
plt.ylabel('Degradación total, $D_{total}$', fontsize=12)
plt.title('Optimización de Distribución de Corriente', fontsize=14)
plt.grid(True)
plt.legend(['Degradación Total', 'Punto Óptimo'], loc='upper left', fontsize=10) # Ajusta la ubicación y tamaño de la leyenda


# Exportar a SVG
canvas = FigureCanvasSVG(fig)
canvas.print_svg("output.svg")

plt.show()
